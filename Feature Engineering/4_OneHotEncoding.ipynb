# %%
import pandas as pd

df = pd.read_csv(r'..\Datasets\global_cars_enhanced.csv')

df

# %%
df = df[['Car_ID', 'Brand', 'Body_Type', 'Fuel_Type', 'Transmission', 'Mileage_km_per_l', 'Car_Age', 'Price_USD']]
df = df.set_index('Car_ID')
df = df.dropna()
df

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['Price_USD']), df['Price_USD'], test_size=0.3, random_state=True)

# %%
y_train, y_test

# %%
df.nunique()
# X_train.head()

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np


ohe = OneHotEncoder(dtype=np.int32, drop='first', sparse_output=False)

X_train_encoded = ohe.fit_transform(X_train[['Body_Type', 'Fuel_Type', 'Transmission']])
X_test_encoded = ohe.fit_transform(X_test[['Body_Type', 'Fuel_Type', 'Transmission']])

# %%
X_train = np.hstack([X_train[['Brand','Mileage_km_per_l','Car_Age']].values, X_train_encoded])
X_test = np.hstack([X_test[['Brand','Mileage_km_per_l','Car_Age']].values, X_test_encoded])

# %%
X_test

# %%
counts = df['Brand'].value_counts()
threshold = 30

temp = counts[counts <= threshold].index
pd.get_dummies(df['Brand'].replace(temp, 'Others'))
